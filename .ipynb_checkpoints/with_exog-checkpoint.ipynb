# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
plt.style.use('fivethirtyeight')
params = {'legend.fontsize': 'medium',
          'figure.figsize': (8, 5),
         'axes.labelsize': 'medium',
         'axes.titlesize':'medium',
         'xtick.labelsize':'small',
         'ytick.labelsize':'small',
         'lines.linewidth' : 1.6}
plt.rcParams.update(params)
import warnings
warnings.filterwarnings('ignore')

# %%
df_global = pd.read_csv('Global_mobility_Report.csv')
df_us = pd.read_csv('us.csv')

# %%
us = df_global[(df_global['country_region'] == 'United States') & (df_global['sub_region_1'].isna()) ]

# %%
us.shape
# Out:
# (210, 14)

# %%
us = us.drop(['country_region_code', 'country_region', 'sub_region_1', 
                   'sub_region_2', 'metro_area', 'iso_3166_2_code', 'census_fips_code'], axis = 1)
df_us = df_us.drop(['deaths'], axis = 1)

# %%
us['date'] = pd.to_datetime(us['date'])
df_us['date'] = pd.to_datetime(df_us['date'])

# %%
us.set_index('date', inplace = True)
df_us.set_index('date', inplace = True)

# %%
df_us['case_day'] = df_us['cases'].diff()
df_us['case_day'][0] = 1
df_us['case_day'] =  df_us['case_day'].astype('int')

# %% [markdown]
# ### Merging both datasets to one

# %%
df = df_us.join(us, how='inner')

# %%
df.shape
# Out:
# (210, 8)

# %%
df.head()
# Out:
#             cases  case_day  \
# date
# 2020-02-15     15         0
# 2020-02-16     15         0
# 2020-02-17     25        10
# 2020-02-18     25         0
# 2020-02-19     25         0
#
#             retail_and_recreation_percent_change_from_baseline  \
# date
# 2020-02-15                                                6.0
# 2020-02-16                                                7.0
# 2020-02-17                                                6.0
# 2020-02-18                                                0.0
# 2020-02-19                                                2.0
#
#             grocery_and_pharmacy_percent_change_from_baseline  \
# date
# 2020-02-15                                                2.0
# 2020-02-16                                                1.0
# 2020-02-17                                                0.0
# 2020-02-18                                               -1.0
# 2020-02-19                                                0.0
#
#             parks_percent_change_from_baseline  \
# date
# 2020-02-15                                15.0
# 2020-02-16                                16.0
# 2020-02-17                                28.0
# 2020-02-18                                 6.0
# 2020-02-19                                 8.0
#
#             transit_stations_percent_change_from_baseline  \
# date
# 2020-02-15                                            3.0
# 2020-02-16                                            2.0
# 2020-02-17                                           -9.0
# 2020-02-18                                            1.0
# 2020-02-19                                            1.0
#
#             workplaces_percent_change_from_baseline  \
# date
# 2020-02-15                                      2.0
# 2020-02-16                                      0.0
# 2020-02-17                                    -24.0
# 2020-02-18                                      0.0
# 2020-02-19                                      1.0
#
#             residential_percent_change_from_baseline
# date
# 2020-02-15                                      -1.0
# 2020-02-16                                      -1.0
# 2020-02-17                                       5.0
# 2020-02-18                                       1.0
# 2020-02-19                                       0.0

# %% [markdown]
# ### Renaming columns

# %%
col = {'retail_and_recreation_percent_change_from_baseline': 'retail', 
      'grocery_and_pharmacy_percent_change_from_baseline': 'grocery',
      'parks_percent_change_from_baseline': 'parks',
      'transit_stations_percent_change_from_baseline': 'transit',
      'workplaces_percent_change_from_baseline' : 'workplace',
      'residential_percent_change_from_baseline': 'residential'}

# %%
df.rename(columns = col, inplace = True)

# %%
df.head()
# Out:
#             cases  case_day  retail  grocery  parks  transit  workplace  \
# date
# 2020-02-15     15         0     6.0      2.0   15.0      3.0        2.0
# 2020-02-16     15         0     7.0      1.0   16.0      2.0        0.0
# 2020-02-17     25        10     6.0      0.0   28.0     -9.0      -24.0
# 2020-02-18     25         0     0.0     -1.0    6.0      1.0        0.0
# 2020-02-19     25         0     2.0      0.0    8.0      1.0        1.0
#
#             residential
# date
# 2020-02-15         -1.0
# 2020-02-16         -1.0
# 2020-02-17          5.0
# 2020-02-18          1.0
# 2020-02-19          0.0

# %%
df.tail()
# Out:
#               cases  case_day  retail  grocery  parks  transit  workplace  \
# date
# 2020-09-07  6317773     25173   -13.0     -4.0  107.0    -40.0      -71.0
# 2020-09-08  6346637     28864   -12.0     -1.0   52.0    -31.0      -38.0
# 2020-09-09  6379950     33313   -10.0     -3.0   58.0    -32.0      -36.0
# 2020-09-10  6417986     38036   -11.0     -2.0   61.0    -32.0      -36.0
# 2020-09-11  6465534     47548   -12.0     -5.0   69.0    -30.0      -34.0
#
#             residential
# date
# 2020-09-07         16.0
# 2020-09-08          9.0
# 2020-09-09          9.0
# 2020-09-10          9.0
# 2020-09-11          8.0

# %%
df[['retail', 'grocery', 'parks', 'transit', 'workplace', 'residential']].plot()
plt.xlabel('Date')
plt.ylabel('Percentage change in visits')
plt.title('Percentage change in visits from March to September')
plt.legend(fontsize = 'small')
plt.show()

# %% [markdown]
# Helper function to reduce the number of x_ticks

# %%
def helper_plot(n):
    every_nth = n
    for n, label in enumerate(ax.xaxis.get_ticklabels()):
        if n % every_nth != 0:
            label.set_visible(False)

# %% [markdown]
# ### Train Test Split

# %%
train = df.loc['2020-02-15':'2020-08-20']
test = df.loc['2020-08-21':]
fig, ax = plt.subplots()
plt.plot(train['case_day'], label = 'Training')
plt.plot(test['case_day'], label = 'Test')
plt.legend(loc = 'upper left')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.title('Training and Testing Split')
#helper_plot(60)
plt.show()

# %% [markdown]
# ### Grid search to look for best parameters since the dataset reduced because of mobility data

# %% [raw]
# def evaluate_arima_model(training, testing ,arima_order):
#     model = ARIMA(training, order = arima_order)
#     model_fit = model.fit(disp=0)
#     preds = model_fit.forecast(steps = 22)[0]
#     error = np.sqrt(mean_squared_error(testing, preds))
#     return error

# %% [markdown]
# def evaluate_models(training, testing, p_values, d_values, q_values):
#     rmse_list = []
#     for p in p_values:
#         for d in d_values:
#             for q in q_values:
#                 order = (p,d,q)
#                 try:
#                     rmse = evaluate_arima_model(training, testing, order)
#                     rmse_list.append([rmse,order])
#                 except:
#                     continue
#     return rmse_list

# %% [raw]
# p_values = range(1,10)
# d_values = range(1,3)
# q_values = range(1,20)

# %% [raw]
# rmse_order = evaluate_models(train['case_day'], test['case_day'], p_values, d_values, q_values)

# %% [raw]
# rmse_order = sorted(rmse_order, key=lambda x: x[0])

# %% [raw]
# rmse_order[0]
# #[4897.97495134121, (8, 1, 4)]

# %% [raw]
# rmse_order[1]
# [5218.394585571898, (6, 1, 4)]

# %% [markdown]
# ### ARIMAX model with Workplace percent as exogenous

# %%
workplace = SARIMAX(train['case_day'], 
                  exog = train['workplace'] , 
                  order=(8, 1, 4))
workplace_fit = workplace.fit(disp=False)

# %%
workplace_preds = workplace_fit.forecast(steps = 22, exog = test['workplace'])

# %%
workplace_preds
# Out:
# 2020-08-21    48353.884141
# 2020-08-22    42041.889000
# 2020-08-23    33717.782770
# 2020-08-24    32390.793351
# 2020-08-25    35456.623265
# 2020-08-26    38657.082059
# 2020-08-27    41640.132595
# 2020-08-28    44054.658944
# 2020-08-29    38960.095876
# 2020-08-30    31211.938172
# 2020-08-31    29988.453665
# 2020-09-01    33223.199079
# 2020-09-02    36683.115375
# 2020-09-03    40028.234288
# 2020-09-04    42816.911068
# 2020-09-05    38052.276310
# 2020-09-06    30820.260365
# 2020-09-07    32070.272310
# 2020-09-08    32466.302795
# 2020-09-09    35910.464418
# 2020-09-10    39506.621526
# 2020-09-11    42008.167012
# Freq: D, dtype: float64

# %%
workplace_rmse = np.sqrt(mean_squared_error(workplace_preds, test['case_day']))
print('Workplace RMSE: ', workplace_rmse)
# Out:
# Workplace RMSE:  5280.147423540722

# %%
fig, ax = plt.subplots()
plt.plot(test['case_day'], label = 'Test')
plt.plot(workplace_preds, label  = 'Predictions')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.legend(loc = 'upper left')
plt.title('Arimax with Workplace Predictions Plot')
plt.show()

# %% [markdown]
# ### ARIMAX model with Residential percent as exogenous

# %%
residential = SARIMAX(train['case_day'], 
                  exog = train['residential'] , 
                  order=(8, 1, 4))
residential_fit = residential.fit(disp=False)

# %%
residential_preds = residential_fit.forecast(steps = 22, exog = test['residential'])

# %%
residential_preds
# Out:
# 2020-08-21    47272.034423
# 2020-08-22    40924.239546
# 2020-08-23    33901.283873
# 2020-08-24    32616.197360
# 2020-08-25    34030.127946
# 2020-08-26    37547.964486
# 2020-08-27    40985.410281
# 2020-08-28    41514.814462
# 2020-08-29    36235.817375
# 2020-08-30    30093.225689
# 2020-08-31    29048.775329
# 2020-09-01    30257.111206
# 2020-09-02    34248.845515
# 2020-09-03    37777.444043
# 2020-09-04    38401.270964
# 2020-09-05    33302.485027
# 2020-09-06    28070.921662
# 2020-09-07    29536.614647
# 2020-09-08    28722.874206
# 2020-09-09    32782.396740
# 2020-09-10    36604.998740
# 2020-09-11    36963.020921
# Freq: D, dtype: float64

# %%
residential_rmse = np.sqrt(mean_squared_error(residential_preds, test['case_day']))
print('Residential RMSE: ', residential_rmse)
# Out:
# Residential RMSE:  6823.813366537111

# %%
fig, ax = plt.subplots()
plt.plot(test['case_day'], label = 'Test')
plt.plot(residential_preds, label  = 'Predictions')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.legend(loc = 'upper left')
plt.title('Arimax with Residential Predictions Plot')
plt.show()

# %% [markdown]
# ### ARIMAX model with Parks percent as exogenous

# %%
parks = SARIMAX(train['case_day'], 
                  exog = train['parks'] , 
                  order=(8, 1, 4))
parks_fit = parks.fit(disp=False)

# %%
parks_preds = parks_fit.forecast(steps = 22, exog = test['parks'])

# %%
parks_preds
# Out:
# 2020-08-21    47829.758847
# 2020-08-22    42166.335645
# 2020-08-23    32953.252985
# 2020-08-24    31106.828240
# 2020-08-25    34665.519734
# 2020-08-26    37427.502390
# 2020-08-27    40317.941705
# 2020-08-28    42534.375122
# 2020-08-29    37760.957229
# 2020-08-30    29300.124196
# 2020-08-31    27363.333333
# 2020-09-01    31361.496482
# 2020-09-02    34433.708083
# 2020-09-03    37703.770455
# 2020-09-04    40295.785159
# 2020-09-05    35956.880386
# 2020-09-06    27751.988409
# 2020-09-07    26008.765619
# 2020-09-08    29628.720848
# 2020-09-09    32973.551585
# 2020-09-10    36424.811611
# 2020-09-11    39086.292480
# Freq: D, dtype: float64

# %%
parks_rmse = np.sqrt(mean_squared_error(parks_preds, test['case_day']))
print('Parks RMSE: ', parks_rmse)
# Out:
# Parks RMSE:  6283.658307120609

# %%
fig, ax = plt.subplots()
plt.plot(test['case_day'], label = 'Test')
plt.plot(parks_preds, label  = 'Predictions')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.legend(loc = 'upper left')
plt.title('Arimax with Parks Predictions Plot')
plt.show()

# %% [markdown]
# ### ARIMAX model with Transit percent as exogenous

# %%
transit = SARIMAX(train['case_day'], 
                  exog = train['transit'] , 
                  order=(8, 1, 4))
transit_fit = transit.fit(disp=False)

# %%
transit_preds = transit_fit.forecast(steps = 22, exog = test['parks'])

# %%
transit_preds
# Out:
# 2020-08-21    41623.515693
# 2020-08-22    34981.394531
# 2020-08-23    27400.760378
# 2020-08-24    26115.458267
# 2020-08-25    28910.610097
# 2020-08-26    31432.030201
# 2020-08-27    34440.701125
# 2020-08-28    37341.986810
# 2020-08-29    32309.493617
# 2020-08-30    23246.299826
# 2020-08-31    22782.515406
# 2020-09-01    25854.949355
# 2020-09-02    29156.943943
# 2020-09-03    31747.927078
# 2020-09-04    33907.604194
# 2020-09-05    27936.853577
# 2020-09-06    20021.433954
# 2020-09-07    17589.777116
# 2020-09-08    25297.829303
# 2020-09-09    28297.806079
# 2020-09-10    31737.029506
# 2020-09-11    34130.082882
# Freq: D, dtype: float64

# %%
transit_rmse = np.sqrt(mean_squared_error(transit_preds, test['case_day']))
print('Transit RMSE: ', transit_rmse)
# Out:
# Transit RMSE:  11362.02093159667

# %%
fig, ax = plt.subplots()
plt.plot(test['case_day'], label = 'Test')
plt.plot(transit_preds, label  = 'Predictions')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.legend(loc = 'upper left')
plt.title('Arimax with Transit Predictions Plot')
plt.show()

# %% [markdown]
# ### ARIMAX model with Grocery percent as exogneous

# %%
grocery = SARIMAX(train['case_day'], 
                  exog = train['grocery'] , 
                  order=(8, 1, 4))
grocery_fit = grocery.fit(disp=False)

# %%
grocery_preds = grocery_fit.forecast(steps = 22, exog = test['grocery'])

# %%
grocery_preds
# Out:
# 2020-08-21    47484.456571
# 2020-08-22    42519.362510
# 2020-08-23    32953.397356
# 2020-08-24    30825.675207
# 2020-08-25    34970.063297
# 2020-08-26    37759.273779
# 2020-08-27    40273.127748
# 2020-08-28    42195.821847
# 2020-08-29    38110.210894
# 2020-08-30    29334.276509
# 2020-08-31    27306.709915
# 2020-09-01    32280.081490
# 2020-09-02    35089.157066
# 2020-09-03    38600.035736
# 2020-09-04    40740.947176
# 2020-09-05    36894.481383
# 2020-09-06    28314.699681
# 2020-09-07    25867.947732
# 2020-09-08    30418.245231
# 2020-09-09    33662.888102
# 2020-09-10    36957.678981
# 2020-09-11    38984.858788
# Freq: D, dtype: float64

# %%
grocery_rmse = np.sqrt(mean_squared_error(grocery_preds, test['case_day']))
print('Grocery RMSE: ', grocery_rmse)
# Out:
# Grocery RMSE:  6063.601461827861

# %%
fig, ax = plt.subplots()
plt.plot(test['case_day'], label = 'Test')
plt.plot(grocery_preds, label  = 'Predictions')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.legend(loc = 'upper left')
plt.title('Arimax with Grocery Predictions Plot')
plt.show()

# %% [markdown]
# ### ARIMAX model with Retail percent as exogenous

# %%
retail = SARIMAX(train['case_day'], 
                  exog = train['retail'] , 
                  order=(8, 1, 4))
retail_fit = retail.fit(disp=False)

# %%
retail_preds = retail_fit.forecast(steps = 22, exog = test['retail'])

# %%
retail_preds
# Out:
# 2020-08-21    48082.602181
# 2020-08-22    42212.283985
# 2020-08-23    32860.904191
# 2020-08-24    31037.758840
# 2020-08-25    34662.297703
# 2020-08-26    37263.853553
# 2020-08-27    40115.262320
# 2020-08-28    42617.063065
# 2020-08-29    37701.889254
# 2020-08-30    29046.220365
# 2020-08-31    27213.368546
# 2020-09-01    31377.080054
# 2020-09-02    34225.935014
# 2020-09-03    37580.224303
# 2020-09-04    40427.842267
# 2020-09-05    35647.483631
# 2020-09-06    27268.340608
# 2020-09-07    25262.608239
# 2020-09-08    29313.506074
# 2020-09-09    32506.379769
# 2020-09-10    35948.562566
# 2020-09-11    38921.928216
# Freq: D, dtype: float64

# %%
retail_rmse = np.sqrt(mean_squared_error(retail_preds, test['case_day']))
print('Retail RMSE: ', retail_rmse)
# Out:
# Retail RMSE:  6350.694197105173

# %%
fig, ax = plt.subplots()
plt.plot(test['case_day'], label = 'Test')
plt.plot(retail_preds, label  = 'Predictions')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.legend(loc = 'upper left')
plt.title('Arimax with Grocery Predictions Plot')
plt.show()

# %% [markdown]
# ### Adding Multiple Exog

# %%
exog = np.array(train[['retail', 'grocery', 'parks', 'transit', 'workplace', 'residential']])

# %%
test_exog = np.array(test[['retail', 'grocery', 'parks', 'transit', 'workplace', 'residential']])

# %%
exog.shape
# Out:
# (188, 6)

# %%
model = ARIMA(train['case_day'], 
                  exog = exog , 
                  order=(7, 1, 6))
model_fit = model.fit()

# %%
model_preds = model_fit.forecast(steps = 22, exog = test_exog)[0]

# %%
model_preds
# Out:
# array([46861.32774921, 39702.85515233, 33640.71338171, 32216.78452449,
#        32383.78609771, 36250.28596635, 38678.1473845 , 38166.9270421 ,
#        34248.82273074, 27630.07022024, 26007.84366136, 27499.84295666,
#        29669.17302049, 32420.89929324, 32763.1659419 , 27061.40474045,
#        21654.82109374, 22048.99807397, 22548.37632611, 25689.24028322,
#        27449.59930644, 27874.02477445])

# %%
model_rmse = np.sqrt(mean_squared_error(model_preds, test['case_day']))
print('Model RMSE: ', model_rmse)
# Out:
# Model RMSE:  10348.682631976233

# %% [markdown]
# ## Using Mask mandatory policy data

# %%
df_mask = pd.read_pickle('mand_mask')

# %%
df_mask.head()
# Out:
#             num
# date
# 2020-04-03    1
# 2020-04-08    2
# 2020-04-10    3
# 2020-04-15    4
# 2020-04-17    5

# %%
df = df.join(df_mask, how = 'outer')

# %%
df['num'].fillna(method = 'ffill', inplace = True)

# %%
df['num'].fillna(0, inplace = True)

# %%
df.rename(columns = {'num': 'states_with_mask'}, inplace = True)

# %%
df.head()
# Out:
#             cases  case_day  retail  grocery  parks  transit  workplace  \
# date
# 2020-02-15     15         0     6.0      2.0   15.0      3.0        2.0
# 2020-02-16     15         0     7.0      1.0   16.0      2.0        0.0
# 2020-02-17     25        10     6.0      0.0   28.0     -9.0      -24.0
# 2020-02-18     25         0     0.0     -1.0    6.0      1.0        0.0
# 2020-02-19     25         0     2.0      0.0    8.0      1.0        1.0
#
#             residential  states_with_mask
# date
# 2020-02-15         -1.0               0.0
# 2020-02-16         -1.0               0.0
# 2020-02-17          5.0               0.0
# 2020-02-18          1.0               0.0
# 2020-02-19          0.0               0.0

# %%
train = df.loc['2020-02-15':'2020-08-20']
test = df.loc['2020-08-21':]

# %%
mask = SARIMAX(train['case_day'], 
                  exog = train['states_with_mask'] , 
                  order=(8, 1, 4))
mask_fit = mask.fit(disp=False)

# %%
mask_preds = mask_fit.forecast(steps = 22, exog = test['states_with_mask'])

# %%
mask_preds
# Out:
# 204    49544.913024
# 205    46244.371752
# 206    37875.797013
# 207    36256.688350
# 208    38597.653697
# 209    39712.345952
# 210    40750.854560
# 211    44392.473375
# 212    42742.937235
# 213    36856.980495
# 214    34890.249538
# 215    37159.241516
# 216    37497.154556
# 217    38204.636816
# 218    40982.971643
# 219    40742.510452
# 220    36306.805947
# 221    34626.941227
# 222    36280.570499
# 223    36625.239466
# 224    36687.756174
# 225    38973.042524
# dtype: float64

# %%
mask_rmse = np.sqrt(mean_squared_error(mask_preds, test['case_day']))
print('Mask RMSE: ', mask_rmse)
# Out:
# Mask RMSE:  5484.766888268694

# %%
fig, ax = plt.subplots()
plt.plot(np.array(test['case_day']), label = 'Test')
plt.plot(np.array(mask_preds), label  = 'Predictions')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.legend(loc = 'upper left')
plt.title('Arimax with Mask Predictions Plot')
plt.show()
