# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot
from chart_studio.plotly import plot_mpl
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from fbprophet import Prophet
from fbprophet.plot import plot_plotly, plot_components_plotly
from pmdarima.arima import auto_arima
import matplotlib.pyplot as plt
import chart_studio.plotly as ply
import cufflinks as cf
from arch import arch_model
from tbats import BATS, TBATS
from keras.models import Sequential
from keras.layers import Dense
plt.rcParams["figure.figsize"] = (8,5)
import warnings
warnings.filterwarnings('ignore')

# %%
df_us = pd.read_csv('us.csv')

# %%
df_us.set_index('date', inplace = True)

# %%
df_us.shape
# Out:
# (239, 2)

# %%
df_us.head()
# Out:
#             cases  deaths
# date
# 2020-01-21      1       0
# 2020-01-22      1       0
# 2020-01-23      1       0
# 2020-01-24      2       0
# 2020-01-25      3       0

# %%
df_us.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_us['case_day'] = df_us['cases'].diff()
df_us['case_day'][0] = 1
df_us['case_day'] =  df_us['case_day'].astype('int')

# %%
df_us['case_day']
# Out:
# date
# 2020-01-21        1
# 2020-01-22        0
# 2020-01-23        0
# 2020-01-24        1
# 2020-01-25        1
#               ...
# 2020-09-11    47548
# 2020-09-12    39149
# 2020-09-13    33369
# 2020-09-14    36836
# 2020-09-15    39224
# Name: case_day, Length: 239, dtype: int32

# %%
df_us['case_day'].describe()
# Out:
# count      239.000000
# mean     27674.108787
# std      21008.903281
# min          0.000000
# 25%       6067.500000
# 50%      26237.000000
# 75%      43120.000000
# max      75682.000000
# Name: case_day, dtype: float64

# %%
df_us['case_day'].plot(ylabel = 'New Cases per Day')
# Out:
# <AxesSubplot:xlabel='date', ylabel='New Cases per Day'>

# %%
test = adfuller(df_us['case_day'])
test_cases_day = pd.Series(test[0:4], index = ['Test Statstic', 'p-value', '#Lags Used', 'Number of Observations Used'])
print(test_cases_day)
# P-value > 0.05 Not Stationary
# Out:
# Test Statstic                   -1.744789
# p-value                          0.408196
# #Lags Used                       0.000000
# Number of Observations Used    238.000000
# dtype: float64

# %% [markdown]
# ## Differencing

# %%
diff1 = df_us['case_day'] - df_us['case_day'].shift(1)

# %%
diff1 = diff1.dropna()

# %%
test = adfuller(diff1)
test_diff1 = pd.Series(test[0:4], index = ['Test Statstic', 'p-value', '#Lags Used', 'Number of Observations Used'])
print(test_diff1)
# pvalue still > 0.05
# Out:
# Test Statstic                   -2.260045
# p-value                          0.185178
# #Lags Used                      14.000000
# Number of Observations Used    223.000000
# dtype: float64

# %%
diff2 = diff1 - diff1.shift(1)
diff2 = diff2.dropna()

# %%
test = adfuller(diff2)
test_diff2 = pd.Series(test[0:4], index = ['Test Statstic', 'p-value', '#Lags Used', 'Number of Observations Used'])
print(test_diff2)
# pvalue still > 0.05
# Out:
# Test Statstic                 -6.783965e+00
# p-value                        2.458934e-09
# #Lags Used                     1.300000e+01
# Number of Observations Used    2.230000e+02
# dtype: float64

# %% [markdown]
# ### p-value < 0.05
# Series stationary at d = 2

# %% [markdown]
# ## Plotting ACF and PACF

# %%
plot_acf(df_us['case_day'], alpha = 0.05) # q = 1-20

# %%
plot_pacf(df_us['case_day'], alpha = 0.05) # p = 3

# %% [markdown]
# ## Train Test Split

# %%
train = df_us['case_day'].loc['2020-01-21':'2020-09-05']
test = df_us['case_day'].loc['2020-09-06':]
plt.plot(train, label = 'Training')
plt.plot(test, label = 'Test')
plt.legend(loc = 'upper left')
plt.show()

# %% [markdown]
# ## ARIMA model

# %%
arima = ARIMA(train, order=(2, 2, 2))
arima_fit = arima.fit(disp= 0)
print(arima_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:            D2.case_day   No. Observations:                  227
# Model:                 ARIMA(2, 2, 2)   Log Likelihood               -2183.376
# Method:                       css-mle   S.D. of innovations           3609.183
# Date:                Fri, 18 Sep 2020   AIC                           4378.752
# Time:                        14:11:58   BIC                           4399.301
# Sample:                    01-23-2020   HQIC                          4387.044
#                          - 09-05-2020
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 1.2530     22.727      0.055      0.956     -43.290      45.796
# ar.L1.D2.case_day     0.7132      0.070     10.235      0.000       0.577       0.850
# ar.L2.D2.case_day    -0.3839      0.068     -5.623      0.000      -0.518      -0.250
# ma.L1.D2.case_day    -1.7468      0.041    -42.552      0.000      -1.827      -1.666
# ma.L2.D2.case_day     0.8098      0.043     18.951      0.000       0.726       0.894
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.9289           -1.3198j            1.6139           -0.1524
# AR.2            0.9289           +1.3198j            1.6139            0.1524
# MA.1            1.0785           -0.2677j            1.1112           -0.0387
# MA.2            1.0785           +0.2677j            1.1112            0.0387
# -----------------------------------------------------------------------------

# %%
residuals = pd.DataFrame(arima_fit.resid)
residuals.plot()
pyplot.show()

# %%
preds = arima_fit.forecast(steps = 10)[0]

# %%
preds
# Out:
# array([38363.66840285, 39532.85877425, 42060.04876133, 43604.97966522,
#        43928.85161885, 43759.80579642, 43708.83054373, 43932.14062232,
#        44306.58267637, 44684.35103226])

# %%
np.sqrt(mean_squared_error(preds, test))
# Out:
# 9070.773231902464

# %%
df_us['case_day'].describe()
# Out:
# count      239.000000
# mean     27674.108787
# std      21008.903281
# min          0.000000
# 25%       6067.500000
# 50%      26237.000000
# 75%      43120.000000
# max      75682.000000
# Name: case_day, dtype: float64

# %%
pyplot.plot(preds)
pyplot.plot(test)

# %% [markdown]
# ### Grid Search for ARIMA

# %% [raw]
# def evaluate_arima_model(training, testing ,arima_order):
#     model = ARIMA(training, order = arima_order)
#     model_fit = model.fit(disp=0)
#     preds = model_fit.forecast(steps = 10)[0]
#     error = np.sqrt(mean_squared_error(testing, preds))
#     return error

# %% [raw]
# def evaluate_models(training, testing, p_values, d_values, q_values):
#     rmse_list = []
#     for p in p_values:
#         for d in d_values:
#             for q in q_values:
#                 order = (p,d,q)
#                 try:
#                     rmse = evaluate_arima_model(training, testing, order)
#                     rmse_list.append([rmse,order])
#                 except:
#                     continue
#     return rmse_list

# %% [raw]
# p_values = range(1,10)
# d_values = range(1,3)
# q_values = range(1,20)

# %% [raw]
# rmse_order = evaluate_models(train, test, p_values, d_values, q_values)

# %% [raw]
# rmse_order = sorted(rmse_order, key=lambda x: x[0])

# %% [raw]
# rmse_order[0]

# %% [markdown]
# ## ARIMA with best parameters

# %%
best_arima = ARIMA(train, order=(7, 1, 6))
best_arima_fit = best_arima.fit(disp= 0)

# %%
best_arima_fit.plot_predict()

# %%
preds = best_arima_fit.forecast(steps = 10)[0]

# %%
best_arima_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:             D.case_day   No. Observations:                  228
# Model:                 ARIMA(7, 1, 6)   Log Likelihood               -2125.942
# Method:                       css-mle   S.D. of innovations                nan
# Date:                Fri, 18 Sep 2020   AIC                           4281.885
# Time:                        14:12:13   BIC                           4333.325
# Sample:                    01-22-2020   HQIC                          4302.639
#                          - 09-05-2020
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const              185.4505        nan        nan        nan         nan         nan
# ar.L1.D.case_day     0.3445   9.19e-06   3.75e+04      0.000       0.344       0.344
# ar.L2.D.case_day    -0.1610        nan        nan        nan         nan         nan
# ar.L3.D.case_day    -0.1997   1.81e-06   -1.1e+05      0.000      -0.200      -0.200
# ar.L4.D.case_day     0.3565   1.61e-05   2.22e+04      0.000       0.356       0.357
# ar.L5.D.case_day    -0.6319        nan        nan        nan         nan         nan
# ar.L6.D.case_day     0.5774   4.03e-06   1.43e+05      0.000       0.577       0.577
# ar.L7.D.case_day     0.3947        nan        nan        nan         nan         nan
# ma.L1.D.case_day    -0.6916      0.049    -14.005      0.000      -0.788      -0.595
# ma.L2.D.case_day     0.4061      0.048      8.546      0.000       0.313       0.499
# ma.L3.D.case_day     0.0072      0.057      0.126      0.900      -0.105       0.120
# ma.L4.D.case_day    -0.4339      0.041    -10.459      0.000      -0.515      -0.353
# ma.L5.D.case_day     0.8711      0.062     14.010      0.000       0.749       0.993
# ma.L6.D.case_day    -0.6281      0.054    -11.598      0.000      -0.734      -0.522
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0664           -0.0000j            1.0664           -0.0000
# AR.2            0.6289           -0.7775j            1.0000           -0.1418
# AR.3            0.6289           +0.7775j            1.0000            0.1418
# AR.4           -0.2219           -0.9751j            1.0000           -0.2856
# AR.5           -0.2219           +0.9751j            1.0000            0.2856
# AR.6           -1.0247           -0.0000j            1.0247           -0.5000
# AR.7           -2.3186           -0.0000j            2.3186           -0.5000
# MA.1           -1.0180           -0.0000j            1.0180           -0.5000
# MA.2           -0.1825           -0.9905j            1.0072           -0.2790
# MA.3           -0.1825           +0.9905j            1.0072            0.2790
# MA.4            0.7616           -0.8103j            1.1121           -0.1299
# MA.5            0.7616           +0.8103j            1.1121            0.1299
# MA.6            1.2467           -0.0000j            1.2467           -0.0000
# -----------------------------------------------------------------------------
# """

# %%
best_rmse = np.sqrt(mean_squared_error(preds, test))
print('Best ARIMA RMSE: ',best_rmse)
# Out:
# Best ARIMA RMSE:  6609.899495639759

# %%
preds
# Out:
# array([36615.30462049, 36765.99442138, 39297.71359229, 39733.49376976,
#        45984.27933713, 50194.65470207, 44271.73178117, 36772.61124462,
#        37835.74510717, 39453.06556671])

# %%
test
# Out:
# date
# 2020-09-06    30030
# 2020-09-07    25173
# 2020-09-08    28864
# 2020-09-09    33313
# 2020-09-10    38036
# 2020-09-11    47548
# 2020-09-12    39149
# 2020-09-13    33369
# 2020-09-14    36836
# 2020-09-15    39224
# Name: case_day, dtype: int32

# %% [markdown]
# ## AUTO ARIMA

# %%
#test.iplot(title="Energy Production Jan 1985--Jan 2018")

# %%
model_auto = auto_arima(train, start_p=1, start_q=1, d = 1,
                           max_p=20, max_q=20, trace=True,
                       error_action='ignore',  m = 1,
                           suppress_warnings=True, 
                           stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=4423.556, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=4425.618, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=4427.290, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=4427.136, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=4424.126, Time=0.01 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=4408.291, Time=0.04 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=4420.824, Time=0.02 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=4404.840, Time=0.07 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=4418.403, Time=0.03 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=4378.172, Time=0.08 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=4384.094, Time=0.04 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=4365.103, Time=0.10 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=4364.313, Time=0.07 sec
#  ARIMA(6,1,0)(0,0,0)[0] intercept   : AIC=4361.554, Time=0.10 sec
#  ARIMA(7,1,0)(0,0,0)[0] intercept   : AIC=4308.406, Time=0.13 sec
#  ARIMA(8,1,0)(0,0,0)[0] intercept   : AIC=4250.291, Time=0.25 sec
#  ARIMA(9,1,0)(0,0,0)[0] intercept   : AIC=4251.077, Time=0.36 sec
#  ARIMA(8,1,1)(0,0,0)[0] intercept   : AIC=4251.467, Time=0.47 sec
#  ARIMA(7,1,1)(0,0,0)[0] intercept   : AIC=4284.112, Time=0.30 sec
#  ARIMA(9,1,1)(0,0,0)[0] intercept   : AIC=4252.003, Time=0.66 sec
#  ARIMA(8,1,0)(0,0,0)[0]             : AIC=4248.714, Time=0.22 sec
#  ARIMA(7,1,0)(0,0,0)[0]             : AIC=4307.471, Time=0.11 sec
#  ARIMA(9,1,0)(0,0,0)[0]             : AIC=4249.564, Time=0.30 sec
#  ARIMA(8,1,1)(0,0,0)[0]             : AIC=4249.929, Time=0.41 sec
#  ARIMA(7,1,1)(0,0,0)[0]             : AIC=4280.623, Time=0.24 sec
#  ARIMA(9,1,1)(0,0,0)[0]             : AIC=4250.096, Time=0.66 sec
#
# Best model:  ARIMA(8,1,0)(0,0,0)[0]
# Total fit time: 4.750 seconds

# %%
model_auto_fit = model_auto.fit(train)

# %%
preds = model_auto_fit.predict(n_periods = 10)

# %%
preds
# Out:
# array([39438.41121831, 40670.07763697, 40429.15763704, 40462.23314101,
#        45455.98581621, 52268.97728407, 45374.59972612, 40726.62829301,
#        43000.62911724, 41370.526741  ])

# %%
test
# Out:
# date
# 2020-09-06    30030
# 2020-09-07    25173
# 2020-09-08    28864
# 2020-09-09    33313
# 2020-09-10    38036
# 2020-09-11    47548
# 2020-09-12    39149
# 2020-09-13    33369
# 2020-09-14    36836
# 2020-09-15    39224
# Name: case_day, dtype: int32

# %%
rmse = np.sqrt(mean_squared_error(preds, test))
print('Auto ARIMA RMSE: ',rmse)
# Out:
# Auto ARIMA RMSE:  8522.844911727185

# %% [markdown]
# ## Simple Exponential Smoothing(SES)

# %%
ses = SimpleExpSmoothing(train)
ses_fit = ses.fit()

# %%
ses_preds = ses_fit.forecast(steps = 10)

# %%
ses_preds
# Out:
# 2020-09-06    42278.0
# 2020-09-07    42278.0
# 2020-09-08    42278.0
# 2020-09-09    42278.0
# 2020-09-10    42278.0
# 2020-09-11    42278.0
# 2020-09-12    42278.0
# 2020-09-13    42278.0
# 2020-09-14    42278.0
# 2020-09-15    42278.0
# Freq: D, dtype: float64

# %%
np.sqrt(mean_squared_error(ses_preds, test))
# Out:
# 9363.60943226489

# %% [markdown]
# ## FBPROPHET

# %%
X = pd.DataFrame(train)

# %%
X.rename(columns = {'case_day':'y'}, inplace = True)
X.index.names = ['ds']
X.head()
# Out:
#             y
# ds
# 2020-01-21  1
# 2020-01-22  0
# 2020-01-23  0
# 2020-01-24  1
# 2020-01-25  1

# %%
X['index'] = np.arange(len(X))

# %%
X['ds'] = X.index

# %%
X.set_index('index', inplace = True)

# %%
model = Prophet()
model.fit(X)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = model.make_future_dataframe(periods = 10)
future.tail()
# Out:
#             ds
# 234 2020-09-11
# 235 2020-09-12
# 236 2020-09-13
# 237 2020-09-14
# 238 2020-09-15

# %%
forecast = model.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds          yhat    yhat_lower    yhat_upper
# 234 2020-09-11  61168.405439  48357.142435  74955.987962
# 235 2020-09-12  58272.808380  44694.782991  71484.030686
# 236 2020-09-13  54663.001131  41394.267746  67508.609873
# 237 2020-09-14  55189.797756  40939.674433  67781.905031
# 238 2020-09-15  57522.935954  44754.779952  71199.415880

# %%
fig1 = model.plot(forecast)

# %%
fig2 = model.plot_components(forecast)

# %%
#plot_plotly(model, forecast)

# %%
#plot_components_plotly(model, forecast)

# %%
np.sqrt(mean_squared_error(test, forecast['yhat'].tail(10)))
# Out:
# 21954.77179086016

# %% [markdown]
# ## TBATS

# %%
tbats = TBATS()
tbats_fit = tbats.fit(train)

# %%
preds_tbats = tbats_fit.forecast(steps=10)

# %%
np.sqrt(mean_squared_error(test, preds_tbats))
# Out:
# 12598.172869639702

# %%
test
# Out:
# date
# 2020-09-06    30030
# 2020-09-07    25173
# 2020-09-08    28864
# 2020-09-09    33313
# 2020-09-10    38036
# 2020-09-11    47548
# 2020-09-12    39149
# 2020-09-13    33369
# 2020-09-14    36836
# 2020-09-15    39224
# Name: case_day, dtype: int32

# %%
preds_tbats
# Out:
# array([48534.49965928, 46243.61367383, 42872.92847179, 44862.45162456,
#        45462.84611931, 47658.24003515, 48481.77819373, 47357.90360872,
#        46284.20757588, 45848.4564317 ])

# %% [markdown]
# ## DNN

# %%
def convert2matrix(data_arr, look_back):
    X, Y =[], []
    for i in range(len(data_arr)-look_back):
        d = i+look_back  
        X.append(data_arr[i:d ,])
        Y.append(data_arr[d,])
    return np.array(X), np.array(Y)

# %%
testt = test.values
trainn = train.values

# %%
look_back = 5

trainX, trainY = convert2matrix(trainn, look_back)
testX, testY = convert2matrix(testt, look_back)

# %%
dnn = Sequential()
dnn.add(Dense(units=32, input_dim=look_back, activation='relu'))
dnn.add(Dense(8, activation='relu'))
dnn.add(Dense(1))
dnn.compile(loss='mean_squared_error',  optimizer='adam',metrics = ['mse', 'mae'])

# %%
dnn_fit = dnn.fit(trainX,trainY, epochs=20, batch_size=30, verbose=1, 
                  validation_data=(testX,testY), )
# Out:
# Epoch 1/20
# 8/8 [==============================] - 0s 14ms/step - loss: 904985408.0000 - mse: 904985408.0000 - mae: 23993.2637 - val_loss: 763466816.0000 - val_mse: 763466816.0000 - val_mae: 27108.4844
# Epoch 2/20
# 8/8 [==============================] - 0s 3ms/step - loss: 423518496.0000 - mse: 423518496.0000 - mae: 16120.7949 - val_loss: 350481280.0000 - val_mse: 350481280.0000 - val_mae: 17708.5234
# Epoch 3/20
# 8/8 [==============================] - 0s 3ms/step - loss: 164181376.0000 - mse: 164181376.0000 - mae: 9754.1504 - val_loss: 160364800.0000 - val_mse: 160364800.0000 - val_mae: 10683.2578
# Epoch 4/20
# 8/8 [==============================] - 0s 3ms/step - loss: 63823348.0000 - mse: 63823348.0000 - mae: 5714.1484 - val_loss: 83693424.0000 - val_mse: 83693424.0000 - val_mae: 6800.2563
# Epoch 5/20
# 8/8 [==============================] - 0s 3ms/step - loss: 30062746.0000 - mse: 30062746.0000 - mae: 3952.4097 - val_loss: 64706720.0000 - val_mse: 64706720.0000 - val_mae: 6449.0498
# Epoch 6/20
# 8/8 [==============================] - 0s 3ms/step - loss: 29005868.0000 - mse: 29005868.0000 - mae: 3816.8521 - val_loss: 61063264.0000 - val_mse: 61063264.0000 - val_mae: 6399.4438
# Epoch 7/20
# 8/8 [==============================] - 0s 3ms/step - loss: 29323734.0000 - mse: 29323734.0000 - mae: 3722.3120 - val_loss: 58005208.0000 - val_mse: 58005208.0000 - val_mae: 6116.4229
# Epoch 8/20
# 8/8 [==============================] - 0s 3ms/step - loss: 26672910.0000 - mse: 26672908.0000 - mae: 3593.4539 - val_loss: 55776628.0000 - val_mse: 55776628.0000 - val_mae: 5947.2305
# Epoch 9/20
# 8/8 [==============================] - 0s 3ms/step - loss: 24042430.0000 - mse: 24042430.0000 - mae: 3468.0640 - val_loss: 55346548.0000 - val_mse: 55346548.0000 - val_mae: 5845.4814
# Epoch 10/20
# 8/8 [==============================] - 0s 3ms/step - loss: 23328960.0000 - mse: 23328960.0000 - mae: 3425.6995 - val_loss: 55635604.0000 - val_mse: 55635604.0000 - val_mae: 5776.6470
# Epoch 11/20
# 8/8 [==============================] - 0s 3ms/step - loss: 22723492.0000 - mse: 22723492.0000 - mae: 3391.8862 - val_loss: 54459232.0000 - val_mse: 54459232.0000 - val_mae: 5699.1650
# Epoch 12/20
# 8/8 [==============================] - 0s 3ms/step - loss: 22386364.0000 - mse: 22386364.0000 - mae: 3359.2874 - val_loss: 52999168.0000 - val_mse: 52999168.0000 - val_mae: 5624.7881
# Epoch 13/20
# 8/8 [==============================] - 0s 3ms/step - loss: 22011220.0000 - mse: 22011220.0000 - mae: 3330.1384 - val_loss: 52032400.0000 - val_mse: 52032400.0000 - val_mae: 5572.7446
# Epoch 14/20
# 8/8 [==============================] - 0s 3ms/step - loss: 21714018.0000 - mse: 21714018.0000 - mae: 3303.8616 - val_loss: 50696152.0000 - val_mse: 50696152.0000 - val_mae: 5458.1499
# Epoch 15/20
# 8/8 [==============================] - 0s 3ms/step - loss: 21387066.0000 - mse: 21387066.0000 - mae: 3275.6160 - val_loss: 48855572.0000 - val_mse: 48855572.0000 - val_mae: 5291.7070
# Epoch 16/20
# 8/8 [==============================] - 0s 3ms/step - loss: 20762210.0000 - mse: 20762210.0000 - mae: 3212.1484 - val_loss: 44077756.0000 - val_mse: 44077756.0000 - val_mae: 4975.0874
# Epoch 17/20
# 8/8 [==============================] - 0s 3ms/step - loss: 19396980.0000 - mse: 19396980.0000 - mae: 3103.9119 - val_loss: 41706760.0000 - val_mse: 41706760.0000 - val_mae: 4725.4141
# Epoch 18/20
# 8/8 [==============================] - 0s 3ms/step - loss: 18672614.0000 - mse: 18672614.0000 - mae: 3025.4080 - val_loss: 39853176.0000 - val_mse: 39853176.0000 - val_mae: 4536.3281
# Epoch 19/20
# 8/8 [==============================] - 0s 3ms/step - loss: 18339024.0000 - mse: 18339024.0000 - mae: 2987.1189 - val_loss: 38816456.0000 - val_mse: 38816456.0000 - val_mae: 4431.0522
# Epoch 20/20
# 8/8 [==============================] - 0s 3ms/step - loss: 18135282.0000 - mse: 18135282.0000 - mae: 2996.8093 - val_loss: 39708500.0000 - val_mse: 39708500.0000 - val_mae: 4426.1382

# %%
train_score = dnn.evaluate(trainX, trainY, verbose=0)
print('Train Score : ', train_score)
# Out:
# Train Score :  [17820756.0, 17820756.0, 2999.364990234375]

# %%
test_score = dnn.evaluate(testX, testY, verbose=0)
print('Test Score : ', test_score)
print('RMSE: ', np.sqrt(test_score[1]))
# Out:
# Test Score :  [39708500.0, 39708500.0, 4426.13818359375]
# RMSE:  6301.468082915282
